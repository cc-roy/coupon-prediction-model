# %%
#import packages and modules
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#create SQLAlchemy engine
db_uri = 'postgresql://postgres:postgres@localhost:5432/coupon' #note that you will need to update the db_uri variable to pull from your local postgres instance
engine = create_engine(db_uri)

#execute SQL query and retrieve data into a DataFrame
query = "SELECT * FROM marketing_data;"
marketing_data_sql = pd.read_sql_query(query, engine)

#print first few rows of the DataFrame
marketing_data_sql.head(25)
# Out:
#       id  year_birth   education marital_status   income  kidhome  teenhome  \
# 0   5524        1957  Graduation         Single  58138.0        0         0
# 1   2174        1954  Graduation         Single  46344.0        1         1
# 2   4141        1965  Graduation       Together  71613.0        0         0
# 3   6182        1984  Graduation       Together  26646.0        1         0
# 4   5324        1981         PhD        Married  58293.0        1         0
# 5   7446        1967      Master       Together  62513.0        0         1
# 6    965        1971  Graduation       Divorced  55635.0        0         1
# 7   6177        1985         PhD        Married  33454.0        1         0
# 8   4855        1974         PhD       Together  30351.0        1         0
# 9   5899        1950         PhD       Together   5648.0        1         1
# 10  1994        1983  Graduation        Married      NaN        1         0
# 11   387        1976       Basic        Married   7500.0        0         0
# 12  2125        1959  Graduation       Divorced  63033.0        0         0
# 13  8180        1952      Master       Divorced  59354.0        1         1
# 14  2569        1987  Graduation        Married  17323.0        0         0
# 15  2114        1946         PhD         Single  82800.0        0         0
# 16  9736        1980  Graduation        Married  41850.0        1         1
# 17  4939        1946  Graduation       Together  37760.0        0         0
# 18  6565        1949      Master        Married  76995.0        0         1
# 19  2278        1985    2n Cycle         Single  33812.0        1         0
# 20  9360        1982  Graduation        Married  37040.0        0         0
# 21  5376        1979  Graduation        Married   2447.0        1         0
# 22  1993        1949         PhD        Married  58607.0        0         1
# 23  4047        1954         PhD        Married  65324.0        0         1
# 24  1409        1951  Graduation       Together  40689.0        0         1
#
#    dt_customer  recency  mntwines  ...  numwebvisitsmonth  acceptedcmp3  \
# 0     9/4/2012       58       635  ...                  7         False
# 1     3/8/2014       38        11  ...                  5         False
# 2    8/21/2013       26       426  ...                  4         False
# 3    2/10/2014       26        11  ...                  6         False
# 4    1/19/2014       94       173  ...                  5         False
# 5     9/9/2013       16       520  ...                  6         False
# 6   11/13/2012       34       235  ...                  6         False
# 7     5/8/2013       32        76  ...                  8         False
# 8     6/6/2013       19        14  ...                  9         False
# 9    3/13/2014       68        28  ...                 20          True
# 10  11/15/2013       11         5  ...                  7         False
# 11  11/13/2012       59         6  ...                  8         False
# 12  11/15/2013       82       194  ...                  2         False
# 13  11/15/2013       53       233  ...                  6         False
# 14  10/10/2012       38         3  ...                  8         False
# 15  11/24/2012       23      1006  ...                  3         False
# 16  12/24/2012       51        53  ...                  8         False
# 17   8/31/2012       20        84  ...                  7         False
# 18   3/28/2013       91      1012  ...                  5         False
# 19   11/3/2012       86         4  ...                  6         False
# 20    8/8/2012       41        86  ...                  8         False
# 21    1/6/2013       42         1  ...                  1         False
# 22  12/23/2012       63       867  ...                  8         False
# 23   1/11/2014        0       384  ...                  4         False
# 24   3/18/2013       69       270  ...                  8         False
#
#     acceptedcmp4  acceptedcmp5  acceptedcmp1  acceptedcmp2  complain  \
# 0          False         False         False         False     False
# 1          False         False         False         False     False
# 2          False         False         False         False     False
# 3          False         False         False         False     False
# 4          False         False         False         False     False
# 5          False         False         False         False     False
# 6          False         False         False         False     False
# 7          False         False         False         False     False
# 8          False         False         False         False     False
# 9          False         False         False         False     False
# 10         False         False         False         False     False
# 11         False         False         False         False     False
# 12         False         False         False         False     False
# 13         False         False         False         False     False
# 14         False         False         False         False     False
# 15         False          True          True         False     False
# 16         False         False         False         False     False
# 17         False         False         False         False     False
# 18         False         False          True         False     False
# 19         False         False         False         False     False
# 20         False         False         False         False     False
# 21         False         False         False         False     False
# 22          True         False         False         False     False
# 23         False         False         False         False     False
# 24         False         False         False         False     False
#
#     z_costcontact  z_revenue  response
# 0               3         11      True
# 1               3         11     False
# 2               3         11     False
# 3               3         11     False
# 4               3         11     False
# 5               3         11     False
# 6               3         11     False
# 7               3         11     False
# 8               3         11      True
# 9               3         11     False
# 10              3         11     False
# 11              3         11     False
# 12              3         11     False
# 13              3         11     False
# 14              3         11     False
# 15              3         11      True
# 16              3         11     False
# 17              3         11     False
# 18              3         11     False
# 19              3         11     False
# 20              3         11     False
# 21              3         11     False
# 22              3         11     False
# 23              3         11     False
# 24              3         11     False
#
# [25 rows x 29 columns]

# %%
# Check the data types
marketing_data_sql.dtypes
# Out:
# id                       int64
# year_birth               int64
# education               object
# marital_status          object
# income                 float64
# kidhome                  int64
# teenhome                 int64
# dt_customer             object
# recency                  int64
# mntwines                 int64
# mntfruits                int64
# mntmeatproducts          int64
# mntfishproducts          int64
# mntsweetproducts         int64
# mntgoldprods             int64
# numdealspurchases        int64
# numwebpurchases          int64
# numcatalogpurchases      int64
# numstorepurchases        int64
# numwebvisitsmonth        int64
# acceptedcmp3              bool
# acceptedcmp4              bool
# acceptedcmp5              bool
# acceptedcmp1              bool
# acceptedcmp2              bool
# complain                  bool
# z_costcontact            int64
# z_revenue                int64
# response                  bool
# dtype: object

# %%
#statistics of the DataFrame
marketing_data_sql.describe(include='all')
# Out:
#                   id   year_birth   education marital_status         income  \
# count    2240.000000  2240.000000        2240           2240    2216.000000
# unique           NaN          NaN           5              8            NaN
# top              NaN          NaN  Graduation        Married            NaN
# freq             NaN          NaN        1127            864            NaN
# mean     5592.159821  1968.805804         NaN            NaN   52247.251354
# std      3246.662198    11.984069         NaN            NaN   25173.076661
# min         0.000000  1893.000000         NaN            NaN    1730.000000
# 25%      2828.250000  1959.000000         NaN            NaN   35303.000000
# 50%      5458.500000  1970.000000         NaN            NaN   51381.500000
# 75%      8427.750000  1977.000000         NaN            NaN   68522.000000
# max     11191.000000  1996.000000         NaN            NaN  666666.000000
#
#             kidhome     teenhome dt_customer      recency     mntwines  ...  \
# count   2240.000000  2240.000000        2240  2240.000000  2240.000000  ...
# unique          NaN          NaN         663          NaN          NaN  ...
# top             NaN          NaN   8/31/2012          NaN          NaN  ...
# freq            NaN          NaN          12          NaN          NaN  ...
# mean       0.444196     0.506250         NaN    49.109375   303.935714  ...
# std        0.538398     0.544538         NaN    28.962453   336.597393  ...
# min        0.000000     0.000000         NaN     0.000000     0.000000  ...
# 25%        0.000000     0.000000         NaN    24.000000    23.750000  ...
# 50%        0.000000     0.000000         NaN    49.000000   173.500000  ...
# 75%        1.000000     1.000000         NaN    74.000000   504.250000  ...
# max        2.000000     2.000000         NaN    99.000000  1493.000000  ...
#
#         numwebvisitsmonth  acceptedcmp3  acceptedcmp4  acceptedcmp5  \
# count         2240.000000          2240          2240          2240
# unique                NaN             2             2             2
# top                   NaN         False         False         False
# freq                  NaN          2077          2073          2077
# mean             5.316518           NaN           NaN           NaN
# std              2.426645           NaN           NaN           NaN
# min              0.000000           NaN           NaN           NaN
# 25%              3.000000           NaN           NaN           NaN
# 50%              6.000000           NaN           NaN           NaN
# 75%              7.000000           NaN           NaN           NaN
# max             20.000000           NaN           NaN           NaN
#
#         acceptedcmp1  acceptedcmp2  complain  z_costcontact  z_revenue  \
# count           2240          2240      2240         2240.0     2240.0
# unique             2             2         2            NaN        NaN
# top            False         False     False            NaN        NaN
# freq            2096          2210      2219            NaN        NaN
# mean             NaN           NaN       NaN            3.0       11.0
# std              NaN           NaN       NaN            0.0        0.0
# min              NaN           NaN       NaN            3.0       11.0
# 25%              NaN           NaN       NaN            3.0       11.0
# 50%              NaN           NaN       NaN            3.0       11.0
# 75%              NaN           NaN       NaN            3.0       11.0
# max              NaN           NaN       NaN            3.0       11.0
#
#         response
# count       2240
# unique         2
# top        False
# freq        1906
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
#
# [11 rows x 29 columns]

# %%
# Check for missing values in the DataFrame
marketing_data_sql.isnull().sum()
# Out:
# id                      0
# year_birth              0
# education               0
# marital_status          0
# income                 24
# kidhome                 0
# teenhome                0
# dt_customer             0
# recency                 0
# mntwines                0
# mntfruits               0
# mntmeatproducts         0
# mntfishproducts         0
# mntsweetproducts        0
# mntgoldprods            0
# numdealspurchases       0
# numwebpurchases         0
# numcatalogpurchases     0
# numstorepurchases       0
# numwebvisitsmonth       0
# acceptedcmp3            0
# acceptedcmp4            0
# acceptedcmp5            0
# acceptedcmp1            0
# acceptedcmp2            0
# complain                0
# z_costcontact           0
# z_revenue               0
# response                0
# dtype: int64

# %%
#make a copy of the dataframe
marketing_data_modeling = marketing_data_sql.copy()

# %%
columns_to_drop = ['id', 'dt_customer', 'acceptedcmp3', 'acceptedcmp4', 'acceptedcmp5', 
                   'acceptedcmp1', 'acceptedcmp2', 'complain', 'z_costcontact', 'z_revenue']
marketing_data_modeling = marketing_data_modeling.drop(columns=columns_to_drop)

#drop rows with missing data
marketing_data_modeling = marketing_data_modeling.dropna()

# %%
# Determine the number of unique values in each column.
unique_values = marketing_data_sql.nunique()
unique_values
# Out:
# id                     2240
# year_birth               59
# education                 5
# marital_status            8
# income                 1974
# kidhome                   3
# teenhome                  3
# dt_customer             663
# recency                 100
# mntwines                776
# mntfruits               158
# mntmeatproducts         558
# mntfishproducts         182
# mntsweetproducts        177
# mntgoldprods            213
# numdealspurchases        15
# numwebpurchases          15
# numcatalogpurchases      14
# numstorepurchases        14
# numwebvisitsmonth        16
# acceptedcmp3              2
# acceptedcmp4              2
# acceptedcmp5              2
# acceptedcmp1              2
# acceptedcmp2              2
# complain                  2
# z_costcontact             1
# z_revenue                 1
# response                  2
# dtype: int64

# %%
# Separate features and target variable
features = ['year_birth', 'education', 'marital_status', 'income', 'kidhome', 'teenhome', 
            'recency', 'mntwines', 'mntfruits', 'mntmeatproducts', 'mntfishproducts', 
            'mntsweetproducts', 'mntgoldprods', 'numdealspurchases', 'numwebpurchases', 
            'numcatalogpurchases', 'numstorepurchases', 'numwebvisitsmonth']
target = 'response'

X = marketing_data_modeling[features]
y = marketing_data_modeling[target].astype(int)

# %%
#data transformation
# Handle categorical variables (one-hot encoding)
X = pd.get_dummies(X, columns=['education', 'marital_status'], drop_first=True)

# List of columns to scale
columns_to_scale = ['income', 'recency', 'mntwines', 'mntfruits', 'mntmeatproducts',
                    'mntfishproducts', 'mntsweetproducts', 'mntgoldprods']

# Scaling the features
scaler = StandardScaler()
X[columns_to_scale] = scaler.fit_transform(X[columns_to_scale])

X.head()
# Out:
#    year_birth    income  kidhome  teenhome   recency  mntwines  mntfruits  \
# 0        1957  0.234063        0         0  0.310532  0.978226   1.549429
# 1        1954 -0.234559        1         1 -0.380509 -0.872024  -0.637328
# 2        1965  0.769478        0         0 -0.795134  0.358511   0.569159
# 3        1984 -1.017239        1         0 -0.795134 -0.872024  -0.561922
# 4        1981  0.240221        1         0  1.554407 -0.391671   0.418348
#
#    mntmeatproducts  mntfishproducts  mntsweetproducts  ...  \
# 0         1.690227         2.454568          1.484827  ...
# 1        -0.717986        -0.651038         -0.633880  ...
# 2        -0.178368         1.340203         -0.146821  ...
# 3        -0.655551        -0.504892         -0.585174  ...
# 4        -0.218505         0.152766         -0.000703  ...
#
#    education_Graduation  education_Master  education_PhD  \
# 0                  True             False          False
# 1                  True             False          False
# 2                  True             False          False
# 3                  True             False          False
# 4                 False             False           True
#
#    marital_status_Alone  marital_status_Divorced  marital_status_Married  \
# 0                 False                    False                   False
# 1                 False                    False                   False
# 2                 False                    False                   False
# 3                 False                    False                   False
# 4                 False                    False                    True
#
#    marital_status_Single  marital_status_Together  marital_status_Widow  \
# 0                   True                    False                 False
# 1                   True                    False                 False
# 2                  False                     True                 False
# 3                  False                     True                 False
# 4                  False                    False                 False
#
#    marital_status_YOLO
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 27 columns]

# %%
X.head()
# Out:
#    year_birth    income  kidhome  teenhome   recency  mntwines  mntfruits  \
# 0        1957  0.234063        0         0  0.310532  0.978226   1.549429
# 1        1954 -0.234559        1         1 -0.380509 -0.872024  -0.637328
# 2        1965  0.769478        0         0 -0.795134  0.358511   0.569159
# 3        1984 -1.017239        1         0 -0.795134 -0.872024  -0.561922
# 4        1981  0.240221        1         0  1.554407 -0.391671   0.418348
#
#    mntmeatproducts  mntfishproducts  mntsweetproducts  ...  \
# 0         1.690227         2.454568          1.484827  ...
# 1        -0.717986        -0.651038         -0.633880  ...
# 2        -0.178368         1.340203         -0.146821  ...
# 3        -0.655551        -0.504892         -0.585174  ...
# 4        -0.218505         0.152766         -0.000703  ...
#
#    education_Graduation  education_Master  education_PhD  \
# 0                  True             False          False
# 1                  True             False          False
# 2                  True             False          False
# 3                  True             False          False
# 4                 False             False           True
#
#    marital_status_Alone  marital_status_Divorced  marital_status_Married  \
# 0                 False                    False                   False
# 1                 False                    False                   False
# 2                 False                    False                   False
# 3                 False                    False                   False
# 4                 False                    False                    True
#
#    marital_status_Single  marital_status_Together  marital_status_Widow  \
# 0                   True                    False                 False
# 1                   True                    False                 False
# 2                  False                     True                 False
# 3                  False                     True                 False
# 4                  False                    False                 False
#
#    marital_status_YOLO
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 27 columns]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Build the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(84, activation='relu'),
    tf.keras.layers.Dense(50, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# C:\Users\karen\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8510 - loss: 0.4444 - val_accuracy: 0.8338 - val_loss: 0.4507
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8399 - loss: 0.4412 - val_accuracy: 0.8338 - val_loss: 0.4503
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8660 - loss: 0.3969 - val_accuracy: 0.8338 - val_loss: 0.4500
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8459 - loss: 0.4298 - val_accuracy: 0.8338 - val_loss: 0.4506
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8465 - loss: 0.4289 - val_accuracy: 0.8338 - val_loss: 0.4507
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8585 - loss: 0.4084 - val_accuracy: 0.8338 - val_loss: 0.4504
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8542 - loss: 0.4160 - val_accuracy: 0.8338 - val_loss: 0.4502
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8486 - loss: 0.4255 - val_accuracy: 0.8338 - val_loss: 0.4501
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8519 - loss: 0.4198 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.4396 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8450 - loss: 0.4317 - val_accuracy: 0.8338 - val_loss: 0.4509
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8515 - loss: 0.4205 - val_accuracy: 0.8338 - val_loss: 0.4504
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8573 - loss: 0.4105 - val_accuracy: 0.8338 - val_loss: 0.4503
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8517 - loss: 0.4200 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8471 - loss: 0.4280 - val_accuracy: 0.8338 - val_loss: 0.4506
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8533 - loss: 0.4172 - val_accuracy: 0.8338 - val_loss: 0.4507
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - loss: 0.4045 - val_accuracy: 0.8338 - val_loss: 0.4500
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8464 - loss: 0.4293 - val_accuracy: 0.8338 - val_loss: 0.4506
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8643 - loss: 0.3985 - val_accuracy: 0.8338 - val_loss: 0.4504
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8571 - loss: 0.4108 - val_accuracy: 0.8338 - val_loss: 0.4502
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8341 - loss: 0.4500 - val_accuracy: 0.8338 - val_loss: 0.4513
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8373 - loss: 0.4453 - val_accuracy: 0.8338 - val_loss: 0.4509
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8537 - loss: 0.4166 - val_accuracy: 0.8338 - val_loss: 0.4507
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8463 - loss: 0.4292 - val_accuracy: 0.8338 - val_loss: 0.4506
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8573 - loss: 0.4103 - val_accuracy: 0.8338 - val_loss: 0.4503
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8306 - loss: 0.4560 - val_accuracy: 0.8338 - val_loss: 0.4509
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8452 - loss: 0.4313 - val_accuracy: 0.8338 - val_loss: 0.4511
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8371 - loss: 0.4458 - val_accuracy: 0.8338 - val_loss: 0.4514
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8597 - loss: 0.4062 - val_accuracy: 0.8338 - val_loss: 0.4500
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8384 - loss: 0.4433 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8478 - loss: 0.4268 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8468 - loss: 0.4292 - val_accuracy: 0.8338 - val_loss: 0.4503
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8451 - loss: 0.4315 - val_accuracy: 0.8338 - val_loss: 0.4504
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8540 - loss: 0.4162 - val_accuracy: 0.8338 - val_loss: 0.4507
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8583 - loss: 0.4086 - val_accuracy: 0.8338 - val_loss: 0.4502
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8517 - loss: 0.4204 - val_accuracy: 0.8338 - val_loss: 0.4503
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8493 - loss: 0.4246 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8420 - loss: 0.4369 - val_accuracy: 0.8338 - val_loss: 0.4510
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8455 - loss: 0.4309 - val_accuracy: 0.8338 - val_loss: 0.4505
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8414 - loss: 0.4378 - val_accuracy: 0.8338 - val_loss: 0.4506
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8458 - loss: 0.4304 - val_accuracy: 0.8338 - val_loss: 0.4513
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8463 - loss: 0.4291 - val_accuracy: 0.8338 - val_loss: 0.4508
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8652 - loss: 0.3964 - val_accuracy: 0.8338 - val_loss: 0.4505
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8555 - loss: 0.4136 - val_accuracy: 0.8338 - val_loss: 0.4502
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8546 - loss: 0.4152 - val_accuracy: 0.8338 - val_loss: 0.4504
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8425 - loss: 0.4359 - val_accuracy: 0.8338 - val_loss: 0.4510
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.4396 - val_accuracy: 0.8338 - val_loss: 0.4504
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8356 - loss: 0.4476 - val_accuracy: 0.8338 - val_loss: 0.4510
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8548 - loss: 0.4149 - val_accuracy: 0.8338 - val_loss: 0.4503
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8550 - loss: 0.4144 - val_accuracy: 0.8338 - val_loss: 0.4505

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8882 - loss: 0.3572
# Test Accuracy: 0.8671171069145203

# %%
X_test
# Out:
#       year_birth    income  kidhome  teenhome   recency  mntwines  mntfruits  \
# 738         1989 -1.381162        1         0 -0.415062 -0.904640  -0.662463
# 1060        1949  0.421090        1         1 -1.589832  2.354052  -0.662463
# 1438        1964 -0.386383        0         0  1.623511 -0.863128   0.242402
# 1157        1974  0.177521        0         0  0.103220 -0.139633   1.976727
# 1416        1966 -1.176651        0         0 -0.069541 -0.898710  -0.084355
# ...          ...       ...      ...       ...       ...       ...        ...
# 1974        1971  0.097060        1         1  0.932470 -0.575509  -0.260301
# 1022        1953  0.487009        1         2  1.105230  2.018991   0.242402
# 1145        1974 -1.231444        1         0  0.241428 -0.818651  -0.662463
# 685         1976  0.565364        0         1  1.727167  0.198393  -0.210030
# 2064        1974  0.603867        0         1  0.483293  1.339973   1.348348
#
#       mntmeatproducts  mntfishproducts  mntsweetproducts  ...  \
# 738         -0.740284        -0.559697         -0.560821  ...
# 1060        -0.544060        -0.687574         -0.658233  ...
# 1438        -0.695688        -0.632770         -0.025056  ...
# 1157         0.321113         3.642005          3.530475  ...
# 1416        -0.695688        -0.541428         -0.512115  ...
# ...               ...              ...               ...  ...
# 1974        -0.579737        -0.559697         -0.439057  ...
# 1022         0.004478        -0.395282         -0.658233  ...
# 1145        -0.633253        -0.651038         -0.609527  ...
# 685         -0.182828         0.171034          0.510709  ...
# 2064         0.223001        -0.157795          1.290003  ...
#
#       education_Graduation  education_Master  education_PhD  \
# 738                  False             False          False
# 1060                 False              True          False
# 1438                  True             False          False
# 1157                  True             False          False
# 1416                 False             False          False
# ...                    ...               ...            ...
# 1974                 False             False          False
# 1022                 False             False           True
# 1145                 False              True          False
# 685                  False             False           True
# 2064                  True             False          False
#
#       marital_status_Alone  marital_status_Divorced  marital_status_Married  \
# 738                  False                    False                    True
# 1060                 False                    False                    True
# 1438                 False                    False                    True
# 1157                 False                    False                   False
# 1416                 False                    False                   False
# ...                    ...                      ...                     ...
# 1974                 False                    False                    True
# 1022                 False                    False                   False
# 1145                 False                    False                   False
# 685                  False                     True                   False
# 2064                 False                    False                    True
#
#       marital_status_Single  marital_status_Together  marital_status_Widow  \
# 738                   False                    False                 False
# 1060                  False                    False                 False
# 1438                  False                    False                 False
# 1157                  False                     True                 False
# 1416                  False                     True                 False
# ...                     ...                      ...                   ...
# 1974                  False                    False                 False
# 1022                  False                     True                 False
# 1145                  False                     True                 False
# 685                   False                    False                 False
# 2064                  False                    False                 False
#
#       marital_status_YOLO
# 738                 False
# 1060                False
# 1438                False
# 1157                False
# 1416                False
# ...                   ...
# 1974                False
# 1022                False
# 1145                False
# 685                 False
# 2064                False
#
# [444 rows x 27 columns]

# %%
from sklearn.metrics import confusion_matrix, classification_report

#predictions
predictions = model.predict(X_test)

# Convert predictions to binary values (0 or 1) based on a threshold (e.g., 0.5)
predictions_binary = (predictions > 0.5).astype(int)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, predictions_binary)
print('Confusion Matrix:')
print(conf_matrix)

# Generate classification report
class_report = classification_report(y_test, predictions_binary)
print('\nClassification Report:')
print(class_report)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Confusion Matrix:
# [[385   0]
#  [ 59   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       385
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.87       444
#    macro avg       0.43      0.50      0.46       444
# weighted avg       0.75      0.87      0.81       444
# C:\Users\karen\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\karen\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\karen\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
